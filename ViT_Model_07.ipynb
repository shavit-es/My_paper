# %%
pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.0 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# 시드 고정
SEED = 430
keras.utils.set_random_seed(SEED)

"""
## 데이터가 바뀌었을 때 손 봐줘야할 부분
"""

NUM_CLASSES = 6
INPUT_SHAPE = (200, 200, 3)

x_train, x_test, y_train, y_test = np.load("/content/drive/MyDrive/steel_surface_200.npy", allow_pickle=True)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (1080, 200, 200, 3) - y_train shape: (1080,)
# x_test shape: (360, 200, 200, 3) - y_test shape: (360,)

# %%
#하이퍼 파라미터 튜닝

# DATA
BUFFER_SIZE = 256 #원래 512
BATCH_SIZE = 64 #원래 256

# AUGMENTATION
IMAGE_SIZE = 200
PATCH_SIZE = 40
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 200 #원래 100

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %%
#데이터 증강기법

data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)


#SPT
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)


# 패치 시각화
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image)
plt.show()
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# %%
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image/255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image/255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    # plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %%
#패치 인코딩
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches


class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores


# MLP
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# ViT 모델 생성
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model


"""
## Compile, train, and evaluate the mode
"""

# Some code is taken from:
# https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2.
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )


def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    model.save_weights('/content/drive/MyDrive/model_weights_steel_surface')
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    return history


# Run experiments with the vanilla ViT

vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT

vit_sl = create_vit_classifier(vanilla=False)
history = run_experiment(vit_sl)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 12s 124ms/step - loss: 3.4989 - accuracy: 0.2809 - top-5-accuracy: 0.8837 - val_loss: 2.4294 - val_accuracy: 0.3056 - val_top-5-accuracy: 0.9630
# Epoch 2/200
# 16/16 [==============================] - 1s 48ms/step - loss: 2.1200 - accuracy: 0.3817 - top-5-accuracy: 0.9527 - val_loss: 1.3833 - val_accuracy: 0.5278 - val_top-5-accuracy: 0.9722
# Epoch 3/200
# 16/16 [==============================] - 1s 45ms/step - loss: 1.5846 - accuracy: 0.5031 - top-5-accuracy: 0.9671 - val_loss: 1.4173 - val_accuracy: 0.4537 - val_top-5-accuracy: 0.9722
# Epoch 4/200
# 16/16 [==============================] - 1s 45ms/step - loss: 1.3485 - accuracy: 0.5350 - top-5-accuracy: 0.9650 - val_loss: 1.1154 - val_accuracy: 0.6111 - val_top-5-accuracy: 0.9722
# Epoch 5/200
# 16/16 [==============================] - 1s 45ms/step - loss: 1.0766 - accuracy: 0.6060 - top-5-accuracy: 0.9846 - val_loss: 1.0797 - val_accuracy: 0.5926 - val_top-5-accuracy: 0.9907
# Epoch 6/200
# 16/16 [==============================] - 1s 44ms/step - loss: 1.0346 - accuracy: 0.6337 - top-5-accuracy: 0.9897 - val_loss: 0.9709 - val_accuracy: 0.6574 - val_top-5-accuracy: 1.0000
# Epoch 7/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.9831 - accuracy: 0.6399 - top-5-accuracy: 0.9918 - val_loss: 0.9044 - val_accuracy: 0.6389 - val_top-5-accuracy: 1.0000
# Epoch 8/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.9877 - accuracy: 0.6574 - top-5-accuracy: 0.9918 - val_loss: 0.9572 - val_accuracy: 0.6759 - val_top-5-accuracy: 1.0000
# Epoch 9/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.9168 - accuracy: 0.6831 - top-5-accuracy: 0.9959 - val_loss: 0.9622 - val_accuracy: 0.6481 - val_top-5-accuracy: 0.9815
# Epoch 10/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.9069 - accuracy: 0.6831 - top-5-accuracy: 0.9938 - val_loss: 0.8483 - val_accuracy: 0.6852 - val_top-5-accuracy: 0.9722
# Epoch 11/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.8220 - accuracy: 0.7335 - top-5-accuracy: 0.9949 - val_loss: 0.8380 - val_accuracy: 0.6944 - val_top-5-accuracy: 1.0000
# Epoch 12/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.7294 - accuracy: 0.7377 - top-5-accuracy: 0.9979 - val_loss: 0.7467 - val_accuracy: 0.7500 - val_top-5-accuracy: 1.0000
# Epoch 13/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.7733 - accuracy: 0.7305 - top-5-accuracy: 0.9959 - val_loss: 0.8302 - val_accuracy: 0.6481 - val_top-5-accuracy: 1.0000
# Epoch 14/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.7451 - accuracy: 0.7325 - top-5-accuracy: 0.9928 - val_loss: 0.7559 - val_accuracy: 0.7407 - val_top-5-accuracy: 1.0000
# Epoch 15/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.7414 - accuracy: 0.7387 - top-5-accuracy: 0.9959 - val_loss: 0.7725 - val_accuracy: 0.7870 - val_top-5-accuracy: 0.9907
# Epoch 16/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.7454 - accuracy: 0.7212 - top-5-accuracy: 0.9979 - val_loss: 0.8672 - val_accuracy: 0.7222 - val_top-5-accuracy: 1.0000
# Epoch 17/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.6930 - accuracy: 0.7623 - top-5-accuracy: 0.9979 - val_loss: 0.7595 - val_accuracy: 0.7130 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.7360 - accuracy: 0.7387 - top-5-accuracy: 0.9979 - val_loss: 0.7828 - val_accuracy: 0.7407 - val_top-5-accuracy: 1.0000
# Epoch 19/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.7234 - accuracy: 0.7562 - top-5-accuracy: 0.9969 - val_loss: 0.7173 - val_accuracy: 0.7130 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.6584 - accuracy: 0.7675 - top-5-accuracy: 0.9990 - val_loss: 0.7979 - val_accuracy: 0.7315 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.6159 - accuracy: 0.7942 - top-5-accuracy: 0.9990 - val_loss: 0.7518 - val_accuracy: 0.7593 - val_top-5-accuracy: 1.0000
# Epoch 22/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.5904 - accuracy: 0.7942 - top-5-accuracy: 0.9979 - val_loss: 0.7616 - val_accuracy: 0.7593 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.5997 - accuracy: 0.8004 - top-5-accuracy: 1.0000 - val_loss: 0.7260 - val_accuracy: 0.7500 - val_top-5-accuracy: 1.0000
# Epoch 24/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.5540 - accuracy: 0.7984 - top-5-accuracy: 0.9969 - val_loss: 0.6406 - val_accuracy: 0.8148 - val_top-5-accuracy: 1.0000
# Epoch 25/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.5202 - accuracy: 0.8189 - top-5-accuracy: 0.9990 - val_loss: 0.6370 - val_accuracy: 0.8241 - val_top-5-accuracy: 1.0000
# Epoch 26/200
# 16/16 [==============================] - 1s 50ms/step - loss: 0.5256 - accuracy: 0.8148 - top-5-accuracy: 0.9990 - val_loss: 0.6709 - val_accuracy: 0.7593 - val_top-5-accuracy: 1.0000
# Epoch 27/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.5276 - accuracy: 0.8066 - top-5-accuracy: 0.9979 - val_loss: 0.8192 - val_accuracy: 0.7037 - val_top-5-accuracy: 1.0000
# Epoch 28/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.5073 - accuracy: 0.8292 - top-5-accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.7870 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.4582 - accuracy: 0.8313 - top-5-accuracy: 0.9990 - val_loss: 0.6313 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.4793 - accuracy: 0.8374 - top-5-accuracy: 0.9969 - val_loss: 0.6921 - val_accuracy: 0.7963 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4432 - accuracy: 0.8498 - top-5-accuracy: 1.0000 - val_loss: 0.7311 - val_accuracy: 0.7593 - val_top-5-accuracy: 1.0000
# Epoch 32/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.4309 - accuracy: 0.8549 - top-5-accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 0.8241 - val_top-5-accuracy: 1.0000
# Epoch 33/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4700 - accuracy: 0.8354 - top-5-accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4848 - accuracy: 0.8405 - top-5-accuracy: 0.9990 - val_loss: 0.6541 - val_accuracy: 0.7963 - val_top-5-accuracy: 1.0000
# Epoch 35/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4377 - accuracy: 0.8488 - top-5-accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 36/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4712 - accuracy: 0.8302 - top-5-accuracy: 1.0000 - val_loss: 0.5593 - val_accuracy: 0.7870 - val_top-5-accuracy: 1.0000
# Epoch 37/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.4081 - accuracy: 0.8663 - top-5-accuracy: 1.0000 - val_loss: 0.6290 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 38/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4374 - accuracy: 0.8426 - top-5-accuracy: 1.0000 - val_loss: 0.4958 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3727 - accuracy: 0.8663 - top-5-accuracy: 1.0000 - val_loss: 0.6640 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.3160 - accuracy: 0.8827 - top-5-accuracy: 0.9979 - val_loss: 0.5434 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 41/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3188 - accuracy: 0.8827 - top-5-accuracy: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3355 - accuracy: 0.8848 - top-5-accuracy: 1.0000 - val_loss: 0.5812 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3835 - accuracy: 0.8652 - top-5-accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 44/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.3743 - accuracy: 0.8663 - top-5-accuracy: 1.0000 - val_loss: 0.5734 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 45/200
# 16/16 [==============================] - 1s 62ms/step - loss: 0.3333 - accuracy: 0.8765 - top-5-accuracy: 1.0000 - val_loss: 0.5621 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 46/200
# 16/16 [==============================] - 1s 54ms/step - loss: 0.2713 - accuracy: 0.9064 - top-5-accuracy: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 47/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3345 - accuracy: 0.8776 - top-5-accuracy: 0.9990 - val_loss: 0.5632 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 48/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3407 - accuracy: 0.8807 - top-5-accuracy: 1.0000 - val_loss: 0.5529 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 49/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3287 - accuracy: 0.8899 - top-5-accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 50/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2478 - accuracy: 0.9146 - top-5-accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8148 - val_top-5-accuracy: 1.0000
# Epoch 51/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2369 - accuracy: 0.9146 - top-5-accuracy: 1.0000 - val_loss: 0.5456 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 52/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2771 - accuracy: 0.8961 - top-5-accuracy: 1.0000 - val_loss: 0.5811 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 53/200
# 16/16 [==============================] - 1s 53ms/step - loss: 0.3442 - accuracy: 0.8786 - top-5-accuracy: 1.0000 - val_loss: 0.5973 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 54/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3107 - accuracy: 0.8868 - top-5-accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 55/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2619 - accuracy: 0.9012 - top-5-accuracy: 1.0000 - val_loss: 0.5283 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 56/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2612 - accuracy: 0.9084 - top-5-accuracy: 1.0000 - val_loss: 0.5054 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 57/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2431 - accuracy: 0.9095 - top-5-accuracy: 1.0000 - val_loss: 0.5197 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 58/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.3020 - accuracy: 0.8940 - top-5-accuracy: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.7963 - val_top-5-accuracy: 1.0000
# Epoch 59/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2631 - accuracy: 0.9095 - top-5-accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 60/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2820 - accuracy: 0.9023 - top-5-accuracy: 0.9990 - val_loss: 0.4699 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 61/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2878 - accuracy: 0.9064 - top-5-accuracy: 1.0000 - val_loss: 0.6041 - val_accuracy: 0.7870 - val_top-5-accuracy: 1.0000
# Epoch 62/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2631 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8148 - val_top-5-accuracy: 1.0000
# Epoch 63/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3444 - accuracy: 0.8848 - top-5-accuracy: 1.0000 - val_loss: 0.4581 - val_accuracy: 0.8241 - val_top-5-accuracy: 1.0000
# Epoch 64/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2288 - accuracy: 0.9239 - top-5-accuracy: 1.0000 - val_loss: 0.3971 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 65/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2489 - accuracy: 0.9198 - top-5-accuracy: 1.0000 - val_loss: 0.5546 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 66/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3490 - accuracy: 0.8909 - top-5-accuracy: 1.0000 - val_loss: 0.5822 - val_accuracy: 0.8241 - val_top-5-accuracy: 1.0000
# Epoch 67/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.3092 - accuracy: 0.8879 - top-5-accuracy: 1.0000 - val_loss: 0.5300 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 68/200
# 16/16 [==============================] - 1s 52ms/step - loss: 0.2552 - accuracy: 0.9156 - top-5-accuracy: 0.9990 - val_loss: 0.6513 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 69/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2023 - accuracy: 0.9424 - top-5-accuracy: 1.0000 - val_loss: 0.5081 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 70/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2664 - accuracy: 0.9156 - top-5-accuracy: 1.0000 - val_loss: 0.5863 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 71/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2510 - accuracy: 0.9136 - top-5-accuracy: 1.0000 - val_loss: 0.5292 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 72/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1936 - accuracy: 0.9331 - top-5-accuracy: 1.0000 - val_loss: 0.4759 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 73/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1870 - accuracy: 0.9311 - top-5-accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 74/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2060 - accuracy: 0.9280 - top-5-accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 75/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1842 - accuracy: 0.9403 - top-5-accuracy: 1.0000 - val_loss: 0.6656 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 76/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2129 - accuracy: 0.9311 - top-5-accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.8333 - val_top-5-accuracy: 1.0000
# Epoch 77/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1936 - accuracy: 0.9321 - top-5-accuracy: 1.0000 - val_loss: 0.5563 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 78/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1806 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 79/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1476 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.5778 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 80/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1645 - accuracy: 0.9414 - top-5-accuracy: 1.0000 - val_loss: 0.6647 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 81/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1818 - accuracy: 0.9414 - top-5-accuracy: 1.0000 - val_loss: 0.5656 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 82/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2242 - accuracy: 0.9249 - top-5-accuracy: 1.0000 - val_loss: 0.5882 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 83/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1730 - accuracy: 0.9372 - top-5-accuracy: 0.9990 - val_loss: 0.6217 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 84/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2137 - accuracy: 0.9342 - top-5-accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 85/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2259 - accuracy: 0.9218 - top-5-accuracy: 1.0000 - val_loss: 0.5633 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 86/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1945 - accuracy: 0.9372 - top-5-accuracy: 1.0000 - val_loss: 0.5670 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 87/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2035 - accuracy: 0.9331 - top-5-accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 88/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2090 - accuracy: 0.9228 - top-5-accuracy: 1.0000 - val_loss: 0.5619 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 89/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1439 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 90/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1573 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.7534 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 91/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2095 - accuracy: 0.9300 - top-5-accuracy: 1.0000 - val_loss: 0.6851 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 92/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1458 - accuracy: 0.9455 - top-5-accuracy: 1.0000 - val_loss: 0.6138 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 93/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1470 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.6157 - val_accuracy: 0.8704 - val_top-5-accuracy: 0.9907
# Epoch 94/200
# 16/16 [==============================] - 1s 51ms/step - loss: 0.1943 - accuracy: 0.9352 - top-5-accuracy: 1.0000 - val_loss: 0.6531 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 95/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1452 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.5344 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 96/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1182 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.5954 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 97/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1360 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.7019 - val_accuracy: 0.8519 - val_top-5-accuracy: 0.9907
# Epoch 98/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2479 - accuracy: 0.9228 - top-5-accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 99/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2185 - accuracy: 0.9259 - top-5-accuracy: 1.0000 - val_loss: 0.5562 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 100/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2264 - accuracy: 0.9300 - top-5-accuracy: 1.0000 - val_loss: 0.5411 - val_accuracy: 0.9074 - val_top-5-accuracy: 0.9907
# Epoch 101/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1423 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.5797 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 102/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1572 - accuracy: 0.9414 - top-5-accuracy: 1.0000 - val_loss: 0.6499 - val_accuracy: 0.8981 - val_top-5-accuracy: 0.9907
# Epoch 103/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1414 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.6590 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 104/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1551 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.6717 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 105/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1932 - accuracy: 0.9352 - top-5-accuracy: 1.0000 - val_loss: 0.6125 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 106/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1718 - accuracy: 0.9393 - top-5-accuracy: 1.0000 - val_loss: 0.6000 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 107/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1427 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.6576 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 108/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1365 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.9074 - val_top-5-accuracy: 0.9907
# Epoch 109/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1808 - accuracy: 0.9434 - top-5-accuracy: 1.0000 - val_loss: 0.6085 - val_accuracy: 0.8796 - val_top-5-accuracy: 0.9907
# Epoch 110/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1902 - accuracy: 0.9249 - top-5-accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 111/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1941 - accuracy: 0.9383 - top-5-accuracy: 1.0000 - val_loss: 0.6374 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 112/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1487 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.5323 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 113/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1568 - accuracy: 0.9434 - top-5-accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 114/200
# 16/16 [==============================] - 1s 79ms/step - loss: 0.1496 - accuracy: 0.9455 - top-5-accuracy: 1.0000 - val_loss: 0.5988 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 115/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1241 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 116/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1260 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.6056 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 117/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1397 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.6206 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 118/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1842 - accuracy: 0.9465 - top-5-accuracy: 1.0000 - val_loss: 0.5580 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 119/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1163 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 120/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1213 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.5592 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 121/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1460 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 122/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1655 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.7171 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 123/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1542 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.5773 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 124/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1215 - accuracy: 0.9650 - top-5-accuracy: 1.0000 - val_loss: 0.5743 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 125/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1294 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.5397 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 126/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1496 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5401 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 127/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1506 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 128/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1413 - accuracy: 0.9547 - top-5-accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 129/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1700 - accuracy: 0.9465 - top-5-accuracy: 1.0000 - val_loss: 0.7060 - val_accuracy: 0.8981 - val_top-5-accuracy: 0.9907
# Epoch 130/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1888 - accuracy: 0.9403 - top-5-accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 131/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1393 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 132/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1504 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.6176 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 133/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1394 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.5204 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 134/200
# 16/16 [==============================] - 1s 52ms/step - loss: 0.1247 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.4816 - val_accuracy: 0.9352 - val_top-5-accuracy: 1.0000
# Epoch 135/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1514 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 136/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1233 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 137/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1734 - accuracy: 0.9414 - top-5-accuracy: 1.0000 - val_loss: 0.6097 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 138/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1536 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5831 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 139/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1205 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 140/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1179 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.5600 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 141/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0957 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 142/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1060 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 143/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1040 - accuracy: 0.9712 - top-5-accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 144/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1093 - accuracy: 0.9650 - top-5-accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 145/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1325 - accuracy: 0.9547 - top-5-accuracy: 1.0000 - val_loss: 0.5744 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 146/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1272 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.4240 - val_accuracy: 0.9352 - val_top-5-accuracy: 1.0000
# Epoch 147/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1180 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.6682 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 148/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1037 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.6206 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 149/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1112 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 150/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1320 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 151/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1296 - accuracy: 0.9547 - top-5-accuracy: 1.0000 - val_loss: 0.4492 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 152/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0963 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 153/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0909 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 154/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1369 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.6173 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 155/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1281 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.6403 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 156/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1400 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.6415 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 157/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1904 - accuracy: 0.9414 - top-5-accuracy: 1.0000 - val_loss: 0.6502 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 158/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1791 - accuracy: 0.9342 - top-5-accuracy: 1.0000 - val_loss: 0.5580 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 159/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1246 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 160/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1112 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.4297 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 161/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1228 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.4622 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 162/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0888 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.5880 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 163/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0990 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 164/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0811 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.6012 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 165/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1104 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.9352 - val_top-5-accuracy: 1.0000
# Epoch 166/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1032 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 167/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0890 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.5319 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 168/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0798 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.5871 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 169/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1228 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.5300 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 170/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1412 - accuracy: 0.9547 - top-5-accuracy: 1.0000 - val_loss: 0.5239 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 171/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1209 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 172/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1255 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.6450 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 173/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1138 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.6837 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 174/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0909 - accuracy: 0.9712 - top-5-accuracy: 1.0000 - val_loss: 0.5097 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 175/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1207 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 176/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1644 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 177/200
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0973 - accuracy: 0.9630 - top-5-accuracy: 1.0000 - val_loss: 0.5827 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 178/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0975 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 179/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0858 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.5724 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 180/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0659 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.5416 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 181/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0905 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.6603 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 182/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1821 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.5717 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 183/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1502 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 184/200
# 16/16 [==============================] - 1s 53ms/step - loss: 0.1199 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.5187 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 185/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1088 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 186/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1228 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.5677 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 187/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1108 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.3937 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 188/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0959 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1189 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0851 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.5445 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0832 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.4641 - val_accuracy: 0.9259 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0716 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.5989 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1021 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1170 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.7012 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0797 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.5445 - val_accuracy: 0.9259 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1010 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.9444 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1182 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0939 - accuracy: 0.9630 - top-5-accuracy: 1.0000 - val_loss: 0.5749 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0895 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1261 - accuracy: 0.9650 - top-5-accuracy: 1.0000 - val_loss: 0.8305 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3337 - accuracy: 0.9194 - top-5-accuracy: 1.0000
# Test accuracy: 91.94%
# Test top 5 accuracy: 100.0%
# Epoch 1/200
# 16/16 [==============================] - 13s 171ms/step - loss: 2.8664 - accuracy: 0.2973 - top-5-accuracy: 0.9156 - val_loss: 3.2552 - val_accuracy: 0.3148 - val_top-5-accuracy: 0.9259
# Epoch 2/200
# 16/16 [==============================] - 1s 86ms/step - loss: 2.4997 - accuracy: 0.3745 - top-5-accuracy: 0.9588 - val_loss: 1.6004 - val_accuracy: 0.4537 - val_top-5-accuracy: 0.9722
# Epoch 3/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.8971 - accuracy: 0.4321 - top-5-accuracy: 0.9619 - val_loss: 1.4481 - val_accuracy: 0.4907 - val_top-5-accuracy: 0.9352
# Epoch 4/200
# 16/16 [==============================] - 1s 88ms/step - loss: 1.5028 - accuracy: 0.4722 - top-5-accuracy: 0.9753 - val_loss: 1.3527 - val_accuracy: 0.4630 - val_top-5-accuracy: 0.9722
# Epoch 5/200
# 16/16 [==============================] - 2s 101ms/step - loss: 1.4037 - accuracy: 0.4866 - top-5-accuracy: 0.9805 - val_loss: 1.3963 - val_accuracy: 0.5000 - val_top-5-accuracy: 0.9537
# Epoch 6/200
# 16/16 [==============================] - 2s 102ms/step - loss: 1.2702 - accuracy: 0.5154 - top-5-accuracy: 0.9774 - val_loss: 1.3311 - val_accuracy: 0.5370 - val_top-5-accuracy: 0.9537
# Epoch 7/200
# 16/16 [==============================] - 1s 91ms/step - loss: 1.2169 - accuracy: 0.5473 - top-5-accuracy: 0.9897 - val_loss: 1.3247 - val_accuracy: 0.5093 - val_top-5-accuracy: 0.9630
# Epoch 8/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.2179 - accuracy: 0.5514 - top-5-accuracy: 0.9856 - val_loss: 1.3658 - val_accuracy: 0.5185 - val_top-5-accuracy: 0.9444
# Epoch 9/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.1901 - accuracy: 0.5545 - top-5-accuracy: 0.9794 - val_loss: 1.1740 - val_accuracy: 0.5648 - val_top-5-accuracy: 0.9722
# Epoch 10/200
# 16/16 [==============================] - 1s 89ms/step - loss: 1.1132 - accuracy: 0.5689 - top-5-accuracy: 0.9887 - val_loss: 1.1306 - val_accuracy: 0.6296 - val_top-5-accuracy: 0.9722
# Epoch 11/200
# 16/16 [==============================] - 1s 88ms/step - loss: 1.0965 - accuracy: 0.5844 - top-5-accuracy: 0.9949 - val_loss: 1.1605 - val_accuracy: 0.5741 - val_top-5-accuracy: 0.9630
# Epoch 12/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.0909 - accuracy: 0.6029 - top-5-accuracy: 0.9866 - val_loss: 1.1751 - val_accuracy: 0.5833 - val_top-5-accuracy: 0.9722
# Epoch 13/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.0971 - accuracy: 0.5864 - top-5-accuracy: 0.9928 - val_loss: 1.1762 - val_accuracy: 0.5833 - val_top-5-accuracy: 0.9815
# Epoch 14/200
# 16/16 [==============================] - 1s 86ms/step - loss: 1.0151 - accuracy: 0.6132 - top-5-accuracy: 0.9897 - val_loss: 1.1270 - val_accuracy: 0.5463 - val_top-5-accuracy: 0.9907
# Epoch 15/200
# 16/16 [==============================] - 1s 87ms/step - loss: 1.0285 - accuracy: 0.6235 - top-5-accuracy: 0.9907 - val_loss: 1.1648 - val_accuracy: 0.5741 - val_top-5-accuracy: 0.9907
# Epoch 16/200
# 16/16 [==============================] - 1s 87ms/step - loss: 1.0004 - accuracy: 0.6502 - top-5-accuracy: 0.9928 - val_loss: 1.0608 - val_accuracy: 0.6019 - val_top-5-accuracy: 0.9907
# Epoch 17/200
# 16/16 [==============================] - 1s 85ms/step - loss: 0.9875 - accuracy: 0.6337 - top-5-accuracy: 0.9907 - val_loss: 1.0430 - val_accuracy: 0.5926 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.9716 - accuracy: 0.6307 - top-5-accuracy: 0.9907 - val_loss: 1.0549 - val_accuracy: 0.6019 - val_top-5-accuracy: 0.9907
# Epoch 19/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.9157 - accuracy: 0.6399 - top-5-accuracy: 0.9887 - val_loss: 1.0213 - val_accuracy: 0.6019 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.8858 - accuracy: 0.6667 - top-5-accuracy: 0.9990 - val_loss: 1.0443 - val_accuracy: 0.6204 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 16/16 [==============================] - 1s 91ms/step - loss: 0.9148 - accuracy: 0.6553 - top-5-accuracy: 0.9969 - val_loss: 1.0424 - val_accuracy: 0.6019 - val_top-5-accuracy: 0.9907
# Epoch 22/200
# 16/16 [==============================] - 1s 90ms/step - loss: 0.8679 - accuracy: 0.6862 - top-5-accuracy: 0.9949 - val_loss: 0.9652 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.8493 - accuracy: 0.6615 - top-5-accuracy: 0.9979 - val_loss: 0.9640 - val_accuracy: 0.6574 - val_top-5-accuracy: 0.9907
# Epoch 24/200
# 16/16 [==============================] - 1s 93ms/step - loss: 0.8309 - accuracy: 0.6924 - top-5-accuracy: 0.9949 - val_loss: 0.9151 - val_accuracy: 0.6944 - val_top-5-accuracy: 0.9907
# Epoch 25/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.7531 - accuracy: 0.7078 - top-5-accuracy: 0.9990 - val_loss: 0.9821 - val_accuracy: 0.6944 - val_top-5-accuracy: 0.9907
# Epoch 26/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.7873 - accuracy: 0.7222 - top-5-accuracy: 0.9949 - val_loss: 0.9037 - val_accuracy: 0.6759 - val_top-5-accuracy: 0.9907
# Epoch 27/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.7102 - accuracy: 0.7572 - top-5-accuracy: 0.9949 - val_loss: 1.0411 - val_accuracy: 0.6667 - val_top-5-accuracy: 0.9907
# Epoch 28/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.6967 - accuracy: 0.7366 - top-5-accuracy: 0.9918 - val_loss: 0.9060 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6899 - accuracy: 0.7387 - top-5-accuracy: 0.9959 - val_loss: 0.9300 - val_accuracy: 0.7037 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6342 - accuracy: 0.7675 - top-5-accuracy: 0.9938 - val_loss: 0.7715 - val_accuracy: 0.7407 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6297 - accuracy: 0.7665 - top-5-accuracy: 1.0000 - val_loss: 0.9332 - val_accuracy: 0.6852 - val_top-5-accuracy: 0.9907
# Epoch 32/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.6199 - accuracy: 0.7819 - top-5-accuracy: 0.9979 - val_loss: 0.8114 - val_accuracy: 0.7500 - val_top-5-accuracy: 0.9907
# Epoch 33/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.6062 - accuracy: 0.7747 - top-5-accuracy: 0.9990 - val_loss: 0.8514 - val_accuracy: 0.7500 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6140 - accuracy: 0.7757 - top-5-accuracy: 0.9990 - val_loss: 0.9121 - val_accuracy: 0.7130 - val_top-5-accuracy: 0.9815
# Epoch 35/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6721 - accuracy: 0.7510 - top-5-accuracy: 0.9990 - val_loss: 0.9286 - val_accuracy: 0.6944 - val_top-5-accuracy: 0.9907
# Epoch 36/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.6574 - accuracy: 0.7675 - top-5-accuracy: 0.9979 - val_loss: 0.9722 - val_accuracy: 0.6759 - val_top-5-accuracy: 0.9907
# Epoch 37/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.5816 - accuracy: 0.7840 - top-5-accuracy: 1.0000 - val_loss: 0.9084 - val_accuracy: 0.6852 - val_top-5-accuracy: 0.9907
# Epoch 38/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.5597 - accuracy: 0.7901 - top-5-accuracy: 0.9949 - val_loss: 0.9094 - val_accuracy: 0.7130 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.5413 - accuracy: 0.7994 - top-5-accuracy: 0.9969 - val_loss: 0.8066 - val_accuracy: 0.7593 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.5282 - accuracy: 0.8128 - top-5-accuracy: 1.0000 - val_loss: 0.8482 - val_accuracy: 0.7222 - val_top-5-accuracy: 0.9907
# Epoch 41/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.4661 - accuracy: 0.8395 - top-5-accuracy: 0.9990 - val_loss: 0.8079 - val_accuracy: 0.7407 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 16/16 [==============================] - 1s 91ms/step - loss: 0.5092 - accuracy: 0.8220 - top-5-accuracy: 0.9990 - val_loss: 0.8178 - val_accuracy: 0.7407 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# ...
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1627 - accuracy: 0.9434 - top-5-accuracy: 1.0000 - val_loss: 0.5715 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 122/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1738 - accuracy: 0.9352 - top-5-accuracy: 1.0000 - val_loss: 0.5377 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 123/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1652 - accuracy: 0.9424 - top-5-accuracy: 0.9990 - val_loss: 0.5449 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 124/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1310 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.6236 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 125/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1119 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.6156 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 126/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1529 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.6487 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 127/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1376 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.4681 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 128/200
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1606 - accuracy: 0.9403 - top-5-accuracy: 1.0000 - val_loss: 0.5644 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 129/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1292 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.7272 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 130/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0869 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.6927 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 131/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1186 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.5806 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 132/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1288 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.6258 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 133/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1570 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.7689 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 134/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1441 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.6738 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 135/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1281 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.5580 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 136/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1687 - accuracy: 0.9403 - top-5-accuracy: 1.0000 - val_loss: 0.6778 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 137/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.1320 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.7200 - val_accuracy: 0.8796 - val_top-5-accuracy: 0.9907
# Epoch 138/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1638 - accuracy: 0.9537 - top-5-accuracy: 0.9990 - val_loss: 0.6071 - val_accuracy: 0.8889 - val_top-5-accuracy: 0.9907
# Epoch 139/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1627 - accuracy: 0.9444 - top-5-accuracy: 0.9990 - val_loss: 0.7022 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 140/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1536 - accuracy: 0.9455 - top-5-accuracy: 1.0000 - val_loss: 0.6437 - val_accuracy: 0.8981 - val_top-5-accuracy: 0.9907
# Epoch 141/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1210 - accuracy: 0.9578 - top-5-accuracy: 1.0000 - val_loss: 0.7303 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 142/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1501 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.5493 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 143/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1355 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.7162 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 144/200
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1357 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.7913 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 145/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1226 - accuracy: 0.9640 - top-5-accuracy: 1.0000 - val_loss: 0.5799 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 146/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1397 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.6868 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 147/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1195 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 148/200
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1200 - accuracy: 0.9547 - top-5-accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 149/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1728 - accuracy: 0.9434 - top-5-accuracy: 1.0000 - val_loss: 0.5797 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 150/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1404 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.5209 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 151/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1145 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.5279 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 152/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1238 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 153/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1121 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 154/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1443 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 155/200
# 16/16 [==============================] - 1s 93ms/step - loss: 0.1033 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.6420 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 156/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.1233 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.6330 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 157/200
# 16/16 [==============================] - 1s 90ms/step - loss: 0.0824 - accuracy: 0.9763 - top-5-accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 158/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1206 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.5860 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 159/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1028 - accuracy: 0.9630 - top-5-accuracy: 1.0000 - val_loss: 0.5599 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 160/200
# 16/16 [==============================] - 1s 90ms/step - loss: 0.1559 - accuracy: 0.9558 - top-5-accuracy: 1.0000 - val_loss: 0.8965 - val_accuracy: 0.8426 - val_top-5-accuracy: 0.9907
# Epoch 161/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1280 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.8262 - val_accuracy: 0.8611 - val_top-5-accuracy: 0.9907
# Epoch 162/200
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1129 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.7539 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 163/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1404 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.7289 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 164/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1542 - accuracy: 0.9434 - top-5-accuracy: 1.0000 - val_loss: 0.6151 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 165/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1510 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.6271 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 166/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1270 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.7230 - val_accuracy: 0.8796 - val_top-5-accuracy: 0.9907
# Epoch 167/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1010 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 0.7736 - val_accuracy: 0.8796 - val_top-5-accuracy: 0.9907
# Epoch 168/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1269 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.6507 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 169/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0982 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.5477 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 170/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1127 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.6148 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 171/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0856 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.6794 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 172/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1030 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.9259 - val_top-5-accuracy: 1.0000
# Epoch 173/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1064 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.9259 - val_top-5-accuracy: 1.0000
# Epoch 174/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0991 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.6543 - val_accuracy: 0.8981 - val_top-5-accuracy: 0.9907
# Epoch 175/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0875 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.6876 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 176/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1000 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.7504 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 177/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0875 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.6466 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 178/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1130 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.6193 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 179/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0952 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 0.7810 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 180/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.0611 - accuracy: 0.9897 - top-5-accuracy: 1.0000 - val_loss: 0.7788 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 181/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0814 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.7504 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 182/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1094 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.6961 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 183/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0929 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.5590 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 184/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0853 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.7004 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 185/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0992 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.6580 - val_accuracy: 0.9167 - val_top-5-accuracy: 1.0000
# Epoch 186/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0868 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.7834 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 187/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.1172 - accuracy: 0.9630 - top-5-accuracy: 1.0000 - val_loss: 0.6606 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 188/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0734 - accuracy: 0.9743 - top-5-accuracy: 1.0000 - val_loss: 0.6956 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0483 - accuracy: 0.9856 - top-5-accuracy: 1.0000 - val_loss: 0.6719 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0796 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.8981 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0731 - accuracy: 0.9712 - top-5-accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0548 - accuracy: 0.9815 - top-5-accuracy: 1.0000 - val_loss: 1.0571 - val_accuracy: 0.8148 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0625 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0802 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 0.9430 - val_accuracy: 0.8519 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 16/16 [==============================] - 1s 92ms/step - loss: 0.0797 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.7839 - val_accuracy: 0.8796 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1708 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.7851 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.1207 - accuracy: 0.9588 - top-5-accuracy: 1.0000 - val_loss: 0.8078 - val_accuracy: 0.8611 - val_top-5-accuracy: 0.9907
# Epoch 198/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.1000 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.5574 - val_accuracy: 0.9444 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 16/16 [==============================] - 1s 87ms/step - loss: 0.1346 - accuracy: 0.9537 - top-5-accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 16/16 [==============================] - 1s 89ms/step - loss: 0.1189 - accuracy: 0.9527 - top-5-accuracy: 1.0000 - val_loss: 0.6118 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3493 - accuracy: 0.9194 - top-5-accuracy: 1.0000
# Test accuracy: 91.94%
# Test top 5 accuracy: 100.0%

# %%
#Test set(vanilla true)정확도
y_pred_test=vit.predict(x_test)
print(y_pred_test, type(y_pred_test), y_pred_test.shape)
y_pred=[]
for ar in y_pred_test:
  y_pred.append(np.argmax(ar))
y_pred = np.array(y_pred)
print(y_pred, y_pred.shape)
print(y_test, y_test.shape)
# Out:
# [[  2.2417355   -7.514479    15.75075      4.580159   -14.056409
#    -4.31421   ]
#  [ -3.0360508    4.7789917   -4.8166714    7.2710996   -4.1846747
#    -4.9573812 ]
#  [ -9.859841     9.293518   -11.410353     1.9268746   -5.827626
#    -1.2232947 ]
#  ...
#  [  2.4513183   -8.823931    19.342274     0.55609185 -14.803591
#    -3.9172878 ]
#  [  2.3578172  -15.04895     31.056114    -2.3667474  -19.774002
#    -3.7972937 ]
#  [ -2.9375038    4.2948823   -4.0110035    5.8015885   -3.7519457
#    -4.4481707 ]] <class 'numpy.ndarray'> (360, 6)
# [2 3 1 2 3 1 2 4 3 2 4 0 1 2 4 2 2 2 0 3 3 4 0 5 2 4 4 4 1 5 5 3 0 0 5 0 3
#  1 2 2 0 3 2 1 0 4 1 0 5 0 2 1 1 0 5 5 4 3 4 2 1 2 0 1 5 0 2 2 3 5 3 3 4 3
#  5 4 1 4 2 2 0 2 0 4 5 0 5 4 4 4 3 4 5 3 4 0 2 2 3 4 0 1 1 3 0 0 1 3 0 0 2
#  1 5 2 4 4 0 4 3 0 3 5 4 0 0 4 1 0 0 0 2 4 3 3 1 2 0 5 2 5 5 0 0 2 4 1 5 2
#  1 4 2 0 4 0 1 5 3 4 3 5 0 3 1 1 4 2 4 5 0 5 5 2 3 0 0 4 0 1 0 1 5 5 2 2 4
#  0 0 2 3 5 3 4 5 1 1 1 4 4 3 5 1 3 5 3 2 4 3 0 4 5 5 5 4 0 5 1 2 2 4 4 5 3
#  5 3 4 3 0 5 0 5 3 0 2 4 5 5 1 3 5 3 5 3 2 4 0 5 0 0 2 3 0 3 4 4 3 4 4 3 0
#  0 0 0 2 4 2 2 2 0 1 5 1 3 2 1 5 3 5 5 4 3 1 4 5 0 1 3 3 2 4 1 0 3 1 4 1 5
#  1 0 2 0 5 4 1 2 0 1 1 4 4 2 0 3 1 4 4 4 5 1 4 4 0 4 4 1 0 4 1 5 4 0 2 5 4
#  4 0 5 1 3 5 0 3 5 3 5 5 0 3 4 3 3 2 5 0 1 0 1 3 2 2 3] (360,)
# [2 3 1 2 3 1 2 4 3 2 4 0 1 2 4 2 2 2 0 3 3 4 0 5 2 4 4 4 1 5 5 3 0 0 5 0 3
#  1 2 2 0 3 2 1 0 4 1 0 5 0 2 1 1 4 1 4 4 3 1 2 1 2 0 1 5 0 2 2 3 5 3 3 4 1
#  5 4 1 4 2 2 2 2 0 4 5 0 5 4 4 4 3 4 5 0 4 0 2 2 3 4 0 1 1 3 0 0 5 3 0 0 2
#  1 5 2 4 3 0 4 3 0 3 5 4 0 0 4 1 0 0 0 2 4 2 1 1 2 0 5 2 5 5 0 0 2 4 1 5 2
#  1 4 2 0 4 0 1 5 3 4 3 5 0 3 1 1 4 2 4 3 0 5 5 2 3 0 0 3 0 1 4 1 5 5 2 2 4
#  0 0 2 3 5 5 4 5 1 1 1 4 4 3 5 1 3 5 3 2 4 3 0 4 5 5 5 4 0 5 1 2 2 4 4 5 3
#  5 3 4 3 0 5 0 5 3 0 2 4 5 0 1 3 5 5 5 3 2 4 0 5 0 0 2 3 0 3 4 4 3 4 4 1 0
#  0 0 0 2 3 2 2 2 0 1 5 1 3 2 1 5 3 5 5 4 3 1 4 5 0 1 5 5 2 3 1 0 3 1 4 1 5
#  3 0 2 0 3 4 1 3 0 1 1 4 4 2 0 3 1 4 4 4 5 1 4 4 2 4 4 1 0 4 1 5 4 0 2 5 4
#  4 0 5 1 3 5 0 3 5 3 5 5 2 3 4 3 1 2 5 0 3 0 1 3 2 2 3] (360,)

# %%
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score
print("accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred, average='weighted'))
print("Recall:",recall_score(y_test, y_pred, average='weighted'))
print("F1-Score:",f1_score(y_test, y_pred, average='weighted'))
# Out:
# accuracy: 0.9194444444444444
# Precision: 0.9202668652446263
# Recall: 0.9194444444444444
# F1-Score: 0.9194984417558271

# %%
#Test set(vanilla False)정확도
y_pred_test_f=vit_sl.predict(x_test)
print(y_pred_test_f, type(y_pred_test_f), y_pred_test_f.shape)
y_pred_f=[]
for ar in y_pred_test_f:
  y_pred_f.append(np.argmax(ar))
y_pred_f = np.array(y_pred_f)
print(y_pred_f, y_pred_f.shape)
print(y_test, y_test.shape)
# Out:
# [[ -2.055324    -1.6417683   11.817091    -3.767018    -3.467799
#    -5.022576  ]
#  [ -5.035939     3.9880471   -9.239936    10.888712    -5.43177
#    -4.6609826 ]
#  [-10.190589    10.96678     -8.645562    -0.98636556  -5.46837
#     1.1357182 ]
#  ...
#  [ -3.5522344   -9.449617    17.161982   -10.446672     5.8230386
#    -1.7317299 ]
#  [ -1.1366113   -3.3564541   12.679002    -6.956571     0.93781304
#    -3.001957  ]
#  [ -0.44475383   1.5869397   -6.026562     8.72335     -3.954445
#    -4.272032  ]] <class 'numpy.ndarray'> (360, 6)
# [2 3 1 2 3 1 2 4 3 2 4 0 1 4 4 2 4 2 0 3 3 4 0 4 2 4 4 4 1 5 5 3 0 4 5 0 3
#  1 4 2 4 3 2 1 0 4 1 4 5 0 2 1 1 4 5 4 4 3 1 2 1 5 0 1 5 0 2 2 3 5 3 3 4 1
#  5 4 1 4 2 2 2 2 0 4 5 0 5 4 0 4 3 4 5 4 4 0 2 2 3 4 0 1 1 3 0 0 1 3 0 0 4
#  1 5 2 4 3 0 4 3 0 3 5 4 0 0 4 1 0 0 0 2 4 2 3 1 4 0 3 2 5 1 0 0 2 4 1 5 2
#  1 4 2 0 4 0 1 5 3 4 3 5 0 3 1 1 4 2 4 3 0 5 5 2 3 0 4 3 0 1 4 1 5 5 2 2 4
#  0 0 2 3 5 5 4 5 1 1 1 4 4 3 5 1 3 5 3 2 4 3 0 4 5 5 3 4 0 5 1 2 2 4 4 5 3
#  5 3 4 3 0 5 0 5 3 0 2 4 5 4 1 3 5 5 5 3 2 4 0 5 0 0 2 3 4 3 4 4 3 4 4 1 0
#  0 0 0 3 0 2 0 2 0 1 5 1 3 4 1 5 3 5 5 4 3 1 4 5 0 1 5 5 2 3 1 0 3 1 4 1 5
#  3 0 4 0 3 4 1 3 0 1 1 4 4 2 0 3 1 4 0 4 5 1 0 4 2 4 4 1 0 4 1 0 4 0 2 5 4
#  4 0 5 1 3 5 0 3 5 3 5 5 2 3 4 3 1 2 5 0 3 0 1 3 2 2 3] (360,)
# [2 3 1 2 3 1 2 4 3 2 4 0 1 2 4 2 2 2 0 3 3 4 0 5 2 4 4 4 1 5 5 3 0 0 5 0 3
#  1 2 2 0 3 2 1 0 4 1 0 5 0 2 1 1 4 1 4 4 3 1 2 1 2 0 1 5 0 2 2 3 5 3 3 4 1
#  5 4 1 4 2 2 2 2 0 4 5 0 5 4 4 4 3 4 5 0 4 0 2 2 3 4 0 1 1 3 0 0 5 3 0 0 2
#  1 5 2 4 3 0 4 3 0 3 5 4 0 0 4 1 0 0 0 2 4 2 1 1 2 0 5 2 5 5 0 0 2 4 1 5 2
#  1 4 2 0 4 0 1 5 3 4 3 5 0 3 1 1 4 2 4 3 0 5 5 2 3 0 0 3 0 1 4 1 5 5 2 2 4
#  0 0 2 3 5 5 4 5 1 1 1 4 4 3 5 1 3 5 3 2 4 3 0 4 5 5 5 4 0 5 1 2 2 4 4 5 3
#  5 3 4 3 0 5 0 5 3 0 2 4 5 0 1 3 5 5 5 3 2 4 0 5 0 0 2 3 0 3 4 4 3 4 4 1 0
#  0 0 0 2 3 2 2 2 0 1 5 1 3 2 1 5 3 5 5 4 3 1 4 5 0 1 5 5 2 3 1 0 3 1 4 1 5
#  3 0 2 0 3 4 1 3 0 1 1 4 4 2 0 3 1 4 4 4 5 1 4 4 2 4 4 1 0 4 1 5 4 0 2 5 4
#  4 0 5 1 3 5 0 3 5 3 5 5 2 3 4 3 1 2 5 0 3 0 1 3 2 2 3] (360,)

# %%
print("accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred, average='weighted'))
print("Recall:",recall_score(y_test, y_pred, average='weighted'))
print("F1-Score:",f1_score(y_test, y_pred, average='weighted'))
# Out:
# accuracy: 0.9194444444444444
# Precision: 0.9202668652446263
# Recall: 0.9194444444444444
# F1-Score: 0.9194984417558271
